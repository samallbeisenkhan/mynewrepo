# %% [markdown]
# Тапсырма 1: Деректерді  сақтау және деректер типтері (айнымалылар)

# %%
name = "Samal"
gpa = 3.85
course = 2
is_society = True

# %%
print(type (name))
print(type (gpa))
print(type (course))
print (type (is_society))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'bool'>

# %% [markdown]
# Тапсырма 2: Шартты Логика (Гранттың Базалық Мөлшерін Анықтау)

# %%
name = "Samal"
gpa = 3.85
course = 2
is_society = True
if gpa>=3.5:
  grant = 50000
elif gpa>=3.0:
  grant = 25000
else:
  grant = 0

print(name)
print(gpa)
print(grant)
# Out:
# Samal
# 3.85
# 50000

# %%
name = "Samal"
gpa = 2.25
course = 2
is_society = True
if gpa>=3.5:
  grant = 50000
elif gpa>=3.0:
  grant = 25000
else:
  grant = 0

print(name)
print(gpa)
print(grant)
# Out:
# Samal
# 2.25
# 0

# %% [markdown]
# Тапсырма 3: Цикл. Олимпиадалар

# %%
bonuses = ["қазақ тілі", "география", "биология", "тарих", "информатика"]
count_olymp = 3
if len(bonuses) >= 3:
  print('базалық грант + 5000')
for i in bonuses:
  print(i)
print("Қатысқан олимпиадалар саны:", count_olymp)
current_grant = grant + count_olymp
print("Студенттің гранты: ", current_grant)

if current_grant == 0:
    i = 0
    while i < 3:
        print("Грант алу үшін GPA-ды көтеру керек!")
        i += 1
# Out:
# базалық грант + 5000
# қазақ тілі
# география
# биология
# тарих
# информатика
# Қатысқан олимпиадалар саны: 3
# Студенттің гранты:  50003

# %%
bonuses = ["қазақ тілі", "география", "биология", "тарих", "информатика"]
count_olymp = 0
if count_olymp == 0:
  i = 0
while i < 3:
  print("Грант алу үшін GPA-ды көтеру керек!")
  i += 1
# Out:
# Грант алу үшін GPA-ды көтеру керек!
# Грант алу үшін GPA-ды көтеру керек!
# Грант алу үшін GPA-ды көтеру керек!

# %% [markdown]
# Тапсырма 4: Функцияны Қолдану. (Әлеуметтік Жеңілдік)

# %%
def social_bonus(special_status):
    if special_status == True:
      return 10000
    else:
      return 0
special_status = social_bonus(is_society)
print("Жалпы грант +", special_status + count_olymp, "$")
# Out:
# Жалпы грант + 10000 $

# %%
def social_bonus(special_status):
    if special_status == False:
      print('қайтару')
    else:
      return 0
special_status = social_bonus(is_society)
print(count_olymp, "$")
# Out:
# 0 $

# %% [markdown]
# Тапсырма 5: Жалпы Грантты Есептеу

# %%
total_grant = grant + count_olymp + special_status
print(" Samal үшін жалпы грант мөлшері: ", total_grant,'$')
# Out:
#  Samal үшін жалпы грант мөлшері:  50000 $
